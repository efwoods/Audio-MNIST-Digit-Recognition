# %% [markdown]
# <a href="https://colab.research.google.com/github/efwoods/Audio-MNIST-Digit-Recognition/blob/main/Audio_MNIST_Digit_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Audio MNIST Digit Recognition**

# %% [markdown]
# <img src="https://cdn.pixabay.com/photo/2018/12/12/15/14/sound-wave-3870974_1280.jpg"></img>

# %% [markdown]
# **Source:** [Pixabay](https://pixabay.com/illustrations/sound-wave-noise-frequency-waveform-3870974/)

# %% [markdown]
# ---------------------
# ## **Context**
# ---------------------
#
# In the last few decades, **significant advances have been achieved in the area of audio recognition**. A lot of research is ongoing globally to recognize audio data or speech using Deep Learning. The most common use case in this field is converting audio to spectrograms and vice versa.
#
# **Audio in its raw form is usually a wave** and to capture that using a data structure, we need to have a huge array of amplitudes even for a very short audio clip. Although it depends on the sampling rate of the sound wave, **this structured data conversion for any audio wave is very voluminous even for low sampling rates.** So it becomes a problem to store and computationally very expensive to do even simple calculations on such data.
#
# One of the best economical alternatives to this is using **spectrograms**. **Spectrograms are created by doing Fourier or Short Time Fourier Transforms on sound waves.** There are various kinds of spectrograms, but the ones we will be using are called **MFCC spectrograms**. To put it in simple terms, a spectrogram is a way to visually encapsulate audio data. It is a graph on a 2-D plane where the X-axis represents time and the Y-axis represents Mel Coefficients. But since it is continuous on a 2-D plane, we can treat this as an image.
#
#
# ---------------------
# ## **Objective**
# ---------------------
#
# **The objective here is to build an Artificial Neural Network that can look at Mel or MFCC spectrograms of audio files and classify them into the 10 classes that represent the 10 unique digits in the spoken Engilsh language.** The audio files are recordings of different speakers uttering a particular digit and the corresponding class to be predicted is the digit itself.
#
# ---------------------
# ## **Dataset**
# ---------------------
#
# The dataset we will use is the **Audio MNIST dataset**, which has audio files (having .wav extension) stored in 10 different folders. Each folder consists of these digits spoken by a particular speaker.

# %% [markdown]
# ## **Understanding the required packages**
#
# * `Librosa`: Librosa is a Python package that helps in dealing with audio data. **librosa.display** visualizes and displays the audio data using Matplotlib. Similarly, there exists a collection of submodules under librosa that provides various other functionalities.
#
# **Run the command in the next cell to install the library**.
# * `IPython.display`: Display is a public API to display the tools available in Ipython. In this case study, we will create an audio object to display the digits in the Audio MNIST data.
# * `tqdm`: tqdm is a Python package that allows us to add a progress bar to our application. This package will help us in iterating over the audio data.

# %% [markdown]
# ## **Installing Librosa**

# %%
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: librosa in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.7.3)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.4.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (21.3)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.56.4)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.2.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa) (5.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa) (0.39.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.43.0->librosa) (3.11.0)

# %% [markdown]
# ## **Importing the necessary libraries and loading the data**

# %%
# For Audio Preprocessing
import librosa
import librosa.display as dsp
from IPython.display import Audio

# For Data Preprocessing
import pandas as pd
import numpy as np
import os

# For Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm


#The data is provided as a zip file
import zipfile
import os

# %%
sns.set_style("dark")

# %% [markdown]
# ## **Mounting the Drive and Unzipping the file**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Audio_MNIST_Archive.zip'

#The data is provided as a zip file so we need to extract the files from the zip file
with zipfile.ZipFile(path, 'r') as zip_ref:
    zip_ref.extractall()

# %% [markdown]
# ## **Let's read and check some of the audio samples**
#
# The below function called "get_audio" takes a digit as an argument and plots the audio wave and returns the audio for a given digit.
#
# Let's understand the functioning of some of the new functions used to create the get_audio() function.
#
# * `.wav`: .wav is a file format like .csv which stores the raw audio format. We will load the .wav file using the librosa package.
# * `dsp.waveshow()`: It visualizes the waveform in the time domain. This method creates a plot that alternates between a raw samples-based view of the signal and an amplitude-envelope view of the signal. The "sr" parameter is the sampling rate, i.e., samples per second.
# * `Audio()`: From the Ipython package, we can create an audio object.

# %%
def get_audio(digit = 0):

    # Audio Sample Directory
    sample = np.random.randint(1, 10)

    # Index of Audio
    index = np.random.randint(1, 5)
    
    # Modified file location
    if sample < 10:
        file = f"/content/drive/MyDrive/data/0{sample}/{digit}_0{sample}_{index}.wav"

    else:
        file = f"/content/drive/MyDrive/data/{sample}/{digit}_{sample}_{index}.wav"

    
    # Get Audio from the location
    # Audio will be automatically resampled to the given rate (default sr = 22050)
    data, sample_rate = librosa.load(file)
    
    # Plot the audio wave
    dsp.waveshow(data, sr = sample_rate)
    plt.show()
    
    # Show the widget
    return Audio(data = data, rate = sample_rate)

# %%
# Show the audio and plot of digit 0
get_audio(0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 1
get_audio(1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 2
get_audio(2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 3
get_audio(3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 4
get_audio(4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 5
get_audio(5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 6
get_audio(6)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 7
get_audio(7)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 8
get_audio(8)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the audio and plot of digit 9
get_audio(9)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Observations:**
#
# - The X-axis represents time and Y-axis represents the amplitude of the vibrations.
# - **The intuition behind the Fourier Transform is that any wave can be broken down or deconstructed as a sum of many composite sine waves.** Since these are composed of sine waves, they are symmetric about the time axis, i.e, they extend equally above and below the time axis at a particular time.
# - **From the various audio plots ranging from 0 to 9, we can observe the amplitude at a given point in time.** For example, when we say "Zero", the "Z" sound has low amplitude and the "ero" sound has higher amplitude. Similarly, the remaining digits can be interpreted by looking at the visualizations.

# %% [markdown]
# ## **Visualizing the spectrogram of the audio data**

# %% [markdown]
# ### **What is a spectrogram?**
#
# **A spectrogram is a visual way of representing the signal strength or “loudness” of a signal over time at various frequencies or time steps present in a particular waveform.** A spectrogram gives a detailed view of our audio. It represents amplitude, frequency, and time in a single plot.
#
# Since spectrograms are continuous plots, they can be interpreted as an image. Different spectrograms have different attributes on their axes and they are usually different to interpret. **In a Research and Development scenario, we make use of a vocoder**, which is an encoder that converts spectrograms back to audio using parameters learned by machine learning. One great vocoder is the WaveNet vocoder which is used in almost all Text-to-Speech architectures.
#
# Here, we will be using **MFCC** spectrograms, which are also called **Mel** spectrograms.

# %%
# A function which returns audio file for a mentioned digit
def get_audio_raw(digit = 0):

    # Audio Sample Directory
    sample = np.random.randint(1, 10)

    # Index of Audio
    index = np.random.randint(1, 5)
    
    # Modified file location
    if sample < 10:
        file = f"/content/drive/MyDrive/data/0{sample}/{digit}_0{sample}_{index}.wav"

    else:
        file = f"/content/drive/MyDrive/data/{sample}/{digit}_{sample}_{index}.wav"

    
    # Get Audio from the location
    data, sample_rate = librosa.load(file)

    # Return audio
    return data, sample_rate

# %% [markdown]
# ### **Extracting features from the audio file**
#
# **Mel-frequency cepstral coefficients (MFCCs) Feature Extraction**
#
# MFCCs are usually the final features used in many machine learning models trained on audio data. They are usually a set of mel coefficients defined for each time step through which the raw audio data can be encoded. So for example, if we have an audio sample extending for 30 time steps, and we are defining each time step by 40 Mel Coefficients, our entire sample can be represented by 40 * 30 Mel Coefficients. And if we want to create a Mel Spectrogram out of it, our spectrogram will resemble a 2-D array of 40 horizontal rows and 30 vertical columns.
#
# In this time step, we will first extract the Mel Coefficents for each audio file and add them to our dataset.
#
# * `extract_features` : Returns the MFCC extracted features for an audio file.
# * `process_and_create_dataset` : Iterate through the audio of each digit, extract the features using the extract_features() function, and append the data into a DataFrame.

# %% [markdown]
# **Creating a function that extracts the data from audio files**

# %%
# Will take an audio file as input and return extracted features using MEL_FREQUENCY CEPSTRAL COEFFICIENT as the output
def extract_features(file):

    # Load audio and its sample rate
    audio, sample_rate = librosa.load(file)

    # Extract features using mel-frequency coefficient
    extracted_features = librosa.feature.mfcc(y = audio,
                                              sr = sample_rate,
                                              n_mfcc = 40)
    
    # Scale the extracted features
    extracted_features = np.mean(extracted_features.T, axis = 0)

    # Return the extracted features
    return extracted_features


def preprocess_and_create_dataset():

    # Path of the folder where the audio files are present
    root_folder_path = "/content/drive/MyDrive/data/"

    # Empty List to create dataset
    dataset = []
    
    # Iterating through folders where each folder has the audio of each digit
    for folder in tqdm(range(1, 11)):

        if folder < 10:

            # Path of the folder
            folder = os.path.join(root_folder_path, "0" + str(folder))

        else:
            folder = os.path.join(root_folder_path, str(folder))
            
        # Iterate through each file of the present folder
        for file in tqdm(os.listdir(folder)):

            # Path of the file
            abs_file_path = os.path.join(folder, file)

            # Pass path of file to the extracted_features() function to create features
            extracted_features = extract_features(abs_file_path) 

            # Class of the audio, i.e., the digit it represents
            class_label = file[0]
            
            # Append a list where the feature represents a column and class of the digit represents another column
            dataset.append([extracted_features, class_label])
    
    # After iterating through all the folders, convert the list to a DataFrame
    return pd.DataFrame(dataset, columns = ['features', 'class'])

# %% [markdown]
# **Now. let's create the dataset using the defined function**

# %%
# Create the dataset by calling the function
dataset = preprocess_and_create_dataset()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 2/500 [00:00<00:28, 17.25it/s]
#   1%|          | 4/500 [00:00<00:31, 15.83it/s]
#   1%|          | 6/500 [00:00<00:41, 11.92it/s]
#   2%|▏         | 8/500 [00:00<00:52,  9.41it/s]
#   2%|▏         | 10/500 [00:00<00:45, 10.67it/s]
#   2%|▏         | 12/500 [00:01<00:40, 12.00it/s]
#   3%|▎         | 14/500 [00:01<00:37, 12.90it/s]
#   3%|▎         | 16/500 [00:01<00:35, 13.69it/s]
#   4%|▎         | 18/500 [00:01<00:33, 14.25it/s]
#   4%|▍         | 20/500 [00:01<00:34, 14.06it/s]
#   4%|▍         | 22/500 [00:01<00:33, 14.33it/s]
#   5%|▍         | 24/500 [00:01<00:33, 14.12it/s]
#   5%|▌         | 26/500 [00:01<00:34, 13.68it/s]
#   6%|▌         | 28/500 [00:02<00:32, 14.51it/s]
#   6%|▌         | 30/500 [00:02<00:31, 14.72it/s]
#   6%|▋         | 32/500 [00:02<00:31, 14.82it/s]
#   7%|▋         | 34/500 [00:02<00:31, 14.56it/s]
#   7%|▋         | 36/500 [00:02<00:32, 14.40it/s]
#   8%|▊         | 38/500 [00:02<00:34, 13.34it/s]
#   8%|▊         | 40/500 [00:02<00:32, 14.00it/s]
#   8%|▊         | 42/500 [00:03<00:32, 14.29it/s]
#   9%|▉         | 44/500 [00:03<00:32, 14.20it/s]
#   9%|▉         | 46/500 [00:03<00:31, 14.29it/s]
#                                             features class
# 0  [-581.59625, 130.0779, 9.152276, 24.682423, 23...     9
# 1  [-614.672, 32.637978, 28.475437, 35.311577, 17...     6
# 2  [-635.71497, 79.67792, 6.1547, 56.964516, 32.4...     3
# 3  [-620.47595, 72.892334, -1.3372321, 58.713444,...     3
# 4  [-636.2319, 123.38601, 7.759686, 43.84134, 38....     9

# %%
# Storing the class as int 
dataset['class'] = [int(x) for x in dataset['class']]

# %%
# Check the frequency of classes in the dataset
dataset['class'].value_counts()
# Out:
# 9    500
# 6    500
# 3    500
# 7    500
# 2    500
# 0    500
# 5    500
# 8    500
# 1    500
# 4    500
# Name: class, dtype: int64

# %% [markdown]
# ### **Visualizing the Mel Frequency Cepstral Coefficients Using a Spectrogram**
#
# * `draw_spectrograms` : From the Mel Coefficients we are extracting for a particular audio, this function is creating the 2-D graph of those coefficients with the X-axis representing time and the Y-axis shows the corresponding Mel coefficients in that time step.

# %%
# A function which returns MFCC
def draw_spectrograms(audio_data, sample_rate):

    # Extract features
    extracted_features = librosa.feature.mfcc(y = audio_data,
                                              sr = sample_rate,
                                              n_mfcc = 40)
    
    # Return features without scaling
    return extracted_features

# %% [markdown]
# The very first MFCC coefficient (0th coefficient) does not provide information about the overall shape of the spectrum. It simply communicates a constant offset or the addition of a constant value to the full spectrum. As a result, when performing classification, many practitioners will disregard the initial MFCC. In the images, you can see those represented by blue pixels.
#
# We can plot the MFCCs, but it's difficult to tell what kind of signal is hiding behind such representation.

# %%
# Creating subplots
fig, ax = plt.subplots(5, 2, figsize = (15, 30))

# Initializing row and column variables for subplots
row = 0
column = 0

for digit in range(10):

    # Get the audio of different classes (0-9)
    audio_data, sample_rate = get_audio_raw(digit)
    
    # Extract their MFCC
    mfcc = draw_spectrograms(audio_data, sample_rate)
    print(f"Shape of MFCC of audio digit {digit} ---> ", mfcc.shape)
    
    # Display the plots and its title
    ax[row,column].set_title(f"MFCC of audio class {digit} across time")
    librosa.display.specshow(mfcc, sr = 22050, ax = ax[row, column])
    
    # Set X-labels and Y-labels
    ax[row,column].set_xlabel("Time")
    ax[row,column].set_ylabel("MFCC Coefficients")
    
    # Conditions for positioning of the plots
    if column == 1:
        column = 0
        row += 1
    else:
        column+=1
        
    
plt.tight_layout(pad = 3)   
plt.show()
# Out:
# Shape of MFCC of audio digit 0 --->  (40, 23)
# Shape of MFCC of audio digit 1 --->  (40, 23)
# Shape of MFCC of audio digit 2 --->  (40, 23)
# Shape of MFCC of audio digit 3 --->  (40, 27)
# Shape of MFCC of audio digit 4 --->  (40, 24)
# Shape of MFCC of audio digit 5 --->  (40, 26)
# Shape of MFCC of audio digit 6 --->  (40, 29)
# Shape of MFCC of audio digit 7 --->  (40, 34)
# Shape of MFCC of audio digit 8 --->  (40, 24)
# Shape of MFCC of audio digit 9 --->  (40, 32)

# %% [markdown]
# **Visual Inspection of MFCC Spectrograms:**
#
# On inspecting them visually, we can see that there are a lot of deviations from the spectrograms of one audio to another. There are a lot of tiny rectangles and bars whose positions are unique to each audio. So, the Artificial Neural Network should be able to perform decently well in identifying these audios.

# %% [markdown]
# ## **Perform the Train-Test-Split**
#
# - Split the data into train and test sets

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X = np.array(dataset['features'].to_list())
Y = np.array(dataset['class'].to_list())

# Create train set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.75, shuffle = True, random_state = 8)

# %%
# Checking the shape of the data
X_train.shape
# Out:
# (3750, 40)

# %% [markdown]
# ## **Modeling**
#
# - Create an artificial neural network to recognize the digit.
#
# **About the libraries:**
#
# - `Keras`: Keras is an open-source deep-learning library in Python. Keras is popular because the API was clean and simple, allowing standard deep learning models to be defined, fit, and evaluated in just a few lines of code.
# - `Sklearn` :
#    * Simple and efficient tools for predictive data analysis
#    * Accessible to everybody, and reusable in various contexts
#    * Built on NumPy, SciPy, and matplotlib
#    * Open source, commercially usable

# %% [markdown]
# ### **Importing the necessary libraries for building the model**

# %%
# To create an ANN model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# To create a checkpoint and save the best model
from tensorflow.keras.callbacks import ModelCheckpoint

# To load the model
from tensorflow.keras.models import load_model

# To evaluate the model
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelBinarizer

# %% [markdown]
# ## **Model Creation**
#
#
# ### **Why are we using Artificial Neural Networks (ANNs)?**
#
#
# **When we convert audios to their corresponding spectrograms, we will have similar spectrograms for similar audios irrespective of who the speaker is, and what their pitch and timber is like.** So local spatiality is not going to be a problem, meaning convolutional layers or other such feature extraction layers would be unnecessary on top of our fully connected layers, as they would just be adding to our computational redundancy. That means, a simple Artificial Neural Network (Feedforward Neural Network) should be enough for this use case.
#
# We will use a Sequential model with multiple connected hidden layers, and an output layer that returns a single, continuous value.
#
# - A Sequential model is a linear stack of layers. Sequential models can be created by giving a list of layer instances.
# - A dense layer of neurons is a simple layer of neurons in which each neuron receives input from all of the neurons in the previous layer.
# - The most popular function employed for hidden layers is the rectified linear activation function, or ReLU activation function. It's popular because it's easy to use and effective in getting around the limitations of other popular activation functions like Sigmoid and Tanh.

# %%
# Create a Sequential Object
model = Sequential()

# Add first layer with 100 neurons to the sequental object
model.add(Dense(100, input_shape = (40, ), activation = 'relu'))

# Add second layer with 100 neurons to the sequental object
model.add(Dense(100, activation = 'relu'))

# Add third layer with 100 neurons to the sequental object
model.add(Dense(100, activation = 'relu'))

# Output layer with 10 neurons as it has 10 classes
model.add(Dense(10, activation = 'softmax'))

# %%
# Print Summary of the model
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 100)               4100
#
#  dense_17 (Dense)            (None, 100)               10100
#
#  dense_18 (Dense)            (None, 100)               10100
#
#  dense_19 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 25,310
# Trainable params: 25,310
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'],
              optimizer = 'adam')

# %% [markdown]
# ### **Model Checkpoint & Training**

# %%
# Set the number of epochs for training
num_epochs = 100

# Set the batch size for training
batch_size = 32

# Fit the model
fit_history = model.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = num_epochs, batch_size = batch_size, verbose = 1)
# Out:
# Epoch 1/100
# 118/118 [==============================] - 1s 4ms/step - loss: 3.7486 - accuracy: 0.4899 - val_loss: 0.7255 - val_accuracy: 0.7296
# Epoch 2/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.5644 - accuracy: 0.7987 - val_loss: 0.5818 - val_accuracy: 0.7592
# Epoch 3/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.3083 - accuracy: 0.8888 - val_loss: 0.2471 - val_accuracy: 0.9192
# Epoch 4/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.2420 - accuracy: 0.9147 - val_loss: 0.2830 - val_accuracy: 0.8888
# Epoch 5/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.2499 - accuracy: 0.9101 - val_loss: 0.1773 - val_accuracy: 0.9304
# Epoch 6/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1420 - accuracy: 0.9488 - val_loss: 0.1695 - val_accuracy: 0.9368
# Epoch 7/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1693 - accuracy: 0.9355 - val_loss: 0.1497 - val_accuracy: 0.9432
# Epoch 8/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.9445 - val_loss: 0.2447 - val_accuracy: 0.9176
# Epoch 9/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 0.9656 - val_loss: 0.1414 - val_accuracy: 0.9520
# Epoch 10/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9653 - val_loss: 0.0881 - val_accuracy: 0.9704
# Epoch 11/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1181 - accuracy: 0.9600 - val_loss: 0.0948 - val_accuracy: 0.9624
# Epoch 12/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9736 - val_loss: 0.1104 - val_accuracy: 0.9696
# Epoch 13/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1115 - accuracy: 0.9621 - val_loss: 0.1222 - val_accuracy: 0.9584
# Epoch 14/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 0.9800 - val_loss: 0.0867 - val_accuracy: 0.9736
# Epoch 15/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0949 - accuracy: 0.9669 - val_loss: 0.0537 - val_accuracy: 0.9840
# Epoch 16/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9797 - val_loss: 0.1400 - val_accuracy: 0.9520
# Epoch 17/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9731 - val_loss: 0.0814 - val_accuracy: 0.9696
# Epoch 18/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9837 - val_loss: 0.1495 - val_accuracy: 0.9488
# Epoch 19/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9803 - val_loss: 0.1278 - val_accuracy: 0.9576
# Epoch 20/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1154 - accuracy: 0.9629 - val_loss: 0.1098 - val_accuracy: 0.9640
# Epoch 21/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 0.9837 - val_loss: 0.1389 - val_accuracy: 0.9592
# Epoch 22/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0689 - accuracy: 0.9768 - val_loss: 0.1323 - val_accuracy: 0.9592
# Epoch 23/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1439 - accuracy: 0.9579 - val_loss: 0.0930 - val_accuracy: 0.9616
# Epoch 24/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0498 - accuracy: 0.9840 - val_loss: 0.0794 - val_accuracy: 0.9768
# Epoch 25/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 0.9835 - val_loss: 0.0803 - val_accuracy: 0.9744
# Epoch 26/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0566 - accuracy: 0.9805 - val_loss: 0.0547 - val_accuracy: 0.9848
# Epoch 27/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9883 - val_loss: 0.0889 - val_accuracy: 0.9720
# Epoch 28/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1279 - accuracy: 0.9605 - val_loss: 0.1407 - val_accuracy: 0.9576
# Epoch 29/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 0.9837 - val_loss: 0.2035 - val_accuracy: 0.9464
# Epoch 30/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1029 - accuracy: 0.9664 - val_loss: 0.0656 - val_accuracy: 0.9800
# Epoch 31/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9917 - val_loss: 0.1024 - val_accuracy: 0.9680
# Epoch 32/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 0.9893 - val_loss: 0.0774 - val_accuracy: 0.9792
# Epoch 33/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9899 - val_loss: 0.0428 - val_accuracy: 0.9880
# Epoch 34/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9811 - val_loss: 0.0455 - val_accuracy: 0.9872
# Epoch 35/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 0.0469 - val_accuracy: 0.9848
# Epoch 36/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9955 - val_loss: 0.0660 - val_accuracy: 0.9808
# Epoch 37/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9885 - val_loss: 0.1023 - val_accuracy: 0.9752
# Epoch 38/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.9848 - val_loss: 0.3506 - val_accuracy: 0.9240
# Epoch 39/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9893 - val_loss: 0.0549 - val_accuracy: 0.9848
# Epoch 40/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9891 - val_loss: 0.0490 - val_accuracy: 0.9864
# Epoch 41/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.9867 - val_loss: 0.2977 - val_accuracy: 0.9280
# Epoch 42/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.
100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9869 - val_loss: 0.0636 - val_accuracy: 0.9792
# Epoch 85/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.0848 - val_accuracy: 0.9784
# Epoch 86/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9917 - val_loss: 0.0865 - val_accuracy: 0.9784
# Epoch 87/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.0350 - val_accuracy: 0.9896
# Epoch 88/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0451 - val_accuracy: 0.9872
# Epoch 89/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0273 - val_accuracy: 0.9904
# Epoch 90/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.1539 - val_accuracy: 0.9616
# Epoch 91/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9896 - val_loss: 0.0871 - val_accuracy: 0.9800
# Epoch 92/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 0.0597 - val_accuracy: 0.9880
# Epoch 93/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9915 - val_loss: 0.0585 - val_accuracy: 0.9840
# Epoch 94/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.0676 - val_accuracy: 0.9840
# Epoch 95/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.0427 - val_accuracy: 0.9880
# Epoch 96/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9939 - val_loss: 0.0379 - val_accuracy: 0.9896
# Epoch 97/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9944 - val_loss: 0.1011 - val_accuracy: 0.9680
# Epoch 98/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 0.9893 - val_loss: 0.0512 - val_accuracy: 0.9864
# Epoch 99/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.1065 - val_accuracy: 0.9712
# Epoch 100/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9941 - val_loss: 0.0376 - val_accuracy: 0.9896

# %% [markdown]
# ### **Model Evaluation**

# %%
# Make predictions on the test set
Y_pred = model.predict(X_test)
Y_pred = [np.argmax(i) for i in Y_pred]
# Out:
# 40/40 [==============================] - 0s 1ms/step

# %%
# Set style as dark
sns.set_style("dark")

# Set figure size
plt.figure(figsize = (15, 8))

# Plot the title
plt.title("CONFUSION MATRIX FOR MNIST AUDIO PREDICTION")

# Confusion matrix
cm = confusion_matrix([int(x) for x in Y_test], Y_pred)

# Plot the confusion matrix as heatmap
sns.heatmap(cm, annot = True, cmap = "cool", fmt = 'g', cbar = False)

# Set X-label and Y-label
plt.xlabel("ACTUAL VALUES")
plt.ylabel("PREDICTED VALUES")

# Show the plot
plt.show()

# Print the metrics
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       119
#            1       1.00      0.98      0.99       133
#            2       0.98      0.99      0.98       128
#            3       0.96      0.96      0.96       112
#            4       1.00      1.00      1.00       136
#            5       1.00      1.00      1.00       127
#            6       1.00      1.00      1.00       133
#            7       1.00      0.99      1.00       116
#            8       1.00      0.98      0.99       125
#            9       0.98      1.00      0.99       121
#
#     accuracy                           0.99      1250
#    macro avg       0.99      0.99      0.99      1250
# weighted avg       0.99      0.99      0.99      1250

# %% [markdown]
# **Observations:**
#
# - From the confusion matrix, we can observe that most of the observations are correctly identified by the model.
# - In very few cases, the model is not able to identify the correct digit. For example, 9 observations are 0 but the model has predicted them as 2.
# - The model has given a great performance with 99% recall, precision and F1-score.

# %% [markdown]
# ### Hypothesis: Removing a layer will decrease the performance of the model.

# %%
# The model below implements two hidden layers.

# Create a Sequential Object
model_H1 = Sequential()

# Add first layer with 100 neurons to the sequental object
model_H1.add(Dense(100, input_shape = (40, ), activation = 'relu'))

# Add second layer with 100 neurons to the sequental object
model_H1.add(Dense(100, activation = 'relu'))

# Output layer with 10 neurons as it has 10 classes
model_H1.add(Dense(10, activation = 'softmax'))

# %%
# Print Summary of the model
model_H1.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 100)               4100
#
#  dense_21 (Dense)            (None, 100)               10100
#
#  dense_22 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 15,210
# Trainable params: 15,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model_H1.compile(loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'],
              optimizer = 'adam')

# %%
# Set the number of epochs for training
num_epochs = 100

# Set the batch size for training
batch_size = 32

# Fit the model
fit_history_2 = model_H1.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = num_epochs, batch_size = batch_size, verbose = 1)
# Out:
# Epoch 1/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1155 - accuracy: 0.9581 - val_loss: 0.1226 - val_accuracy: 0.9528
# Epoch 2/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2067 - accuracy: 0.9459 - val_loss: 0.3944 - val_accuracy: 0.8920
# Epoch 3/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.9627 - val_loss: 0.1888 - val_accuracy: 0.9488
# Epoch 4/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9821 - val_loss: 0.1235 - val_accuracy: 0.9592
# Epoch 5/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9592 - val_loss: 0.3250 - val_accuracy: 0.9064
# Epoch 6/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0949 - accuracy: 0.9677 - val_loss: 0.1215 - val_accuracy: 0.9656
# Epoch 7/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9776 - val_loss: 0.0942 - val_accuracy: 0.9712
# Epoch 8/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9787 - val_loss: 0.0780 - val_accuracy: 0.9760
# Epoch 9/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0735 - accuracy: 0.9755 - val_loss: 0.2539 - val_accuracy: 0.9328
# Epoch 10/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0717 - accuracy: 0.9776 - val_loss: 0.0751 - val_accuracy: 0.9776
# Epoch 11/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9763 - val_loss: 0.0671 - val_accuracy: 0.9736
# Epoch 12/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9843 - val_loss: 0.1113 - val_accuracy: 0.9656
# Epoch 13/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 0.9885 - val_loss: 0.0936 - val_accuracy: 0.9704
# Epoch 14/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9797 - val_loss: 0.0638 - val_accuracy: 0.9760
# Epoch 15/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9856 - val_loss: 0.1131 - val_accuracy: 0.9624
# Epoch 16/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0946 - accuracy: 0.9688 - val_loss: 0.1141 - val_accuracy: 0.9608
# Epoch 17/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9805 - val_loss: 0.0933 - val_accuracy: 0.9728
# Epoch 18/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9893 - val_loss: 0.0920 - val_accuracy: 0.9720
# Epoch 19/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9896 - val_loss: 0.0703 - val_accuracy: 0.9744
# Epoch 20/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9861 - val_loss: 0.1481 - val_accuracy: 0.9592
# Epoch 21/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0444 - accuracy: 0.9840 - val_loss: 0.0648 - val_accuracy: 0.9768
# Epoch 22/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0543 - accuracy: 0.9824 - val_loss: 0.1489 - val_accuracy: 0.9640
# Epoch 23/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 0.9848 - val_loss: 0.1454 - val_accuracy: 0.9592
# Epoch 24/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9872 - val_loss: 0.0734 - val_accuracy: 0.9752
# Epoch 25/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9861 - val_loss: 0.1002 - val_accuracy: 0.9736
# Epoch 26/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9824 - val_loss: 0.0941 - val_accuracy: 0.9696
# Epoch 27/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9819 - val_loss: 0.1050 - val_accuracy: 0.9696
# Epoch 28/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9877 - val_loss: 0.0728 - val_accuracy: 0.9744
# Epoch 29/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.9869 - val_loss: 0.0736 - val_accuracy: 0.9768
# Epoch 30/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 0.9808 - val_loss: 0.0873 - val_accuracy: 0.9744
# Epoch 31/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 0.9875 - val_loss: 0.0454 - val_accuracy: 0.9856
# Epoch 32/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9883 - val_loss: 0.1590 - val_accuracy: 0.9568
# Epoch 33/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0634 - accuracy: 0.9795 - val_loss: 0.2080 - val_accuracy: 0.9480
# Epoch 34/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 0.9827 - val_loss: 0.1139 - val_accuracy: 0.9680
# Epoch 35/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9803 - val_loss: 0.0555 - val_accuracy: 0.9816
# Epoch 36/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.0506 - val_accuracy: 0.9848
# Epoch 37/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.0795 - val_accuracy: 0.9736
# Epoch 38/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 0.9944 - val_loss: 0.1218 - val_accuracy: 0.9696
# Epoch 39/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9939 - val_loss: 0.0856 - val_accuracy: 0.9816
# Epoch 40/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0926 - val_accuracy: 0.9752
# Epoch 41/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9907 - val_loss: 0.0718 - val_accuracy: 0.9784
# Epoch 42/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9949 - val_loss: 0.1109 - val_accuracy: 0.9632
# Epoch 43/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 0.0645 - val_accuracy: 0.9800
# Epoch 44/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9928 - val_loss: 0.1188 - val_accuracy: 0.9664
# Epoch 45/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.9840 - val_loss: 0.0633 - val_accuracy: 0.9768
# Epoch 46/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 0.9888 - val_loss: 0.0860 - val_accuracy: 0.9744
# Epoch 47/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0633 - accuracy: 0.9827 - val_loss: 0.1934 - val_accuracy: 0.9536
# Epoch 48/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9888 - val_loss: 0.0570 - val_accuracy: 0.9824
# Epoch 49/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9944 - val_loss: 0.1406 - val_accuracy: 0.9712
# Epoch 50/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9957 - val_loss: 0.0468 - val_accuracy: 0.9896
# Epoch 51/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0454 - val_accuracy: 0.9864
# Epoch 52/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0473 - val_accuracy: 0.9872
# Epoch 53/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.1468 - val_accuracy: 0.9608
# Epoch 54/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 0.9907 - val_loss: 0.0741 - val_accuracy: 0.9808
# Epoch 55/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9955 - val_loss: 0.0791 - val_accuracy: 0.9808
# Epoch 56/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9931 - val_loss: 0.1224 - val_accuracy: 0.9680
# Epoch 57/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9744 - val_loss: 0.0886 - val_accuracy: 0.9808
# Epoch 58/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0979 - val_accuracy: 0.9744
# Epoch 59/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9947 - val_loss: 0.0620 - val_accuracy: 0.9840
# Epoch 60/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9856 - val_loss: 0.0695 - val_accuracy: 0.9840
# Epoch 61/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 0.9891 - val_loss: 0.0606 - val_accuracy: 0.9832
# Epoch 62/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0448 - val_accuracy: 0.9888
# Epoch 63/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0695 - val_accuracy: 0.9824
# Epoch 64/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0572 - val_accuracy: 0.9816
# Epoch 65/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 0.0695 - val_accuracy: 0.9824
# Epoch 66/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0479 - val_accuracy: 0.9896
# Epoch 67/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0544 - val_accuracy: 0.9856
# Epoch 68/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0465 - val_accuracy: 0.9880
# Epoch 69/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 0.9880
# Epoch 70/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0614 - val_accuracy: 0.9816
# Epoch 71/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0570 - val_accuracy: 0.9872
# Epoch 72/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0464 - val_accuracy: 0.9856
# Epoch 73/100
# 118/118 [==============================] - 0s 3ms/step - loss: 6.2056e-04 - accuracy: 1.0000 - val_loss: 0.0521 - val_accuracy: 0.9840
# Epoch 74/100
# 118/118 [==============================] - 0s 3ms/step - loss: 4.9739e-04 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9896
# Epoch 75/100
# 118/118 [==============================] - 0s 3ms/step - loss: 5.5557e-04 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9880
# Epoch 76/100
# 118/118 [==============================] - 0s 3ms/step - loss: 8.6509e-04 - accuracy: 1.0000 - val_loss: 0.0560 - val_accuracy: 0.9856
# Epoch 77/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1083 - val_accuracy: 0.9760
# Epoch 78/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9960 - val_loss: 0.2012 - val_accuracy: 0.9584
# Epoch 79/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1103 - accuracy: 0.9683 - val_loss: 0.0977 - val_accuracy: 0.9736
# Epoch 80/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9875 - val_loss: 0.1351 - val_accuracy: 0.9664
# Epoch 81/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.0465 - val_accuracy: 0.9888
# Epoch 82/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0443 - val_accuracy: 0.9864
# Epoch 83/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 0.9973 - val_loss: 0.0672 - val_accuracy: 0.9792
# Epoch 84/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0418 - val_accuracy: 0.9888
# Epoch 85/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0777 - val_accuracy: 0.9832
# Epoch 86/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0428 - val_accuracy: 0.9888
# Epoch 87/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0526 - val_accuracy: 0.9864
# Epoch 88/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0403 - val_accuracy: 0.9896
# Epoch 89/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 0.9981 - val_loss: 0.0770 - val_accuracy: 0.9824
# Epoch 90/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0973 - val_accuracy: 0.9768
# Epoch 91/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9899 - val_loss: 0.0801 - val_accuracy: 0.9792
# Epoch 92/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0484 - val_accuracy: 0.9872
# Epoch 93/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9888
# Epoch 94/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0936 - val_accuracy: 0.9800
# Epoch 95/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0517 - accuracy: 0.9848 - val_loss: 0.0473 - val_accuracy: 0.9856
# Epoch 96/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0708 - val_accuracy: 0.9840
# Epoch 97/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.9981 - val_loss: 0.0351 - val_accuracy: 0.9912
# Epoch 98/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0333 - val_accuracy: 0.9912
# Epoch 99/100
# 118/118 [==============================] - 0s 3ms/step - loss: 3.2757e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9896
# Epoch 100/100
# 118/118 [==============================] - 0s 3ms/step - loss: 3.0823e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9896

# %%
# Set style as dark
sns.set_style("dark")

# Set figure size
plt.figure(figsize = (15, 8))

# Plot the title
plt.title("CONFUSION MATRIX FOR MNIST AUDIO PREDICTION WITH ONLY 2 HIDDEN LAYERS")

# Confusion matrix
cm = confusion_matrix([int(x) for x in Y_test], Y_pred)

# Plot the confusion matrix as heatmap
sns.heatmap(cm, annot = True, cmap = "cool", fmt = 'g', cbar = False)

# Set X-label and Y-label
plt.xlabel("ACTUAL VALUES")
plt.ylabel("PREDICTED VALUES")

# Show the plot
plt.show()

# Print the metrics
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       119
#            1       1.00      0.98      0.99       133
#            2       0.98      0.99      0.98       128
#            3       0.96      0.96      0.96       112
#            4       1.00      1.00      1.00       136
#            5       1.00      1.00      1.00       127
#            6       1.00      1.00      1.00       133
#            7       1.00      0.99      1.00       116
#            8       1.00      0.98      0.99       125
#            9       0.98      1.00      0.99       121
#
#     accuracy                           0.99      1250
#    macro avg       0.99      0.99      0.99      1250
# weighted avg       0.99      0.99      0.99      1250

# %% [markdown]
# ##### Observation: With 1 less layer, the model maintained consitent accuracy with 10,000 less parameters.

# %% [markdown]
# ### Hypothesis: The model will continue to have consistent accuracy near 100% *with* 1 hidden layer.

# %%
# Create a Sequential Object
model_H2 = Sequential()

# Add first layer with 100 neurons to the sequental object
model_H2.add(Dense(100, input_shape = (40, ), activation = 'relu'))

# Output layer with 10 neurons as it has 10 classes
model_H2.add(Dense(10, activation = 'softmax'))

# %%
# Print Summary of the model
model_H2.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_23 (Dense)            (None, 100)               4100
#
#  dense_24 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 5,110
# Trainable params: 5,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model_H2.compile(loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'],
              optimizer = 'adam')

# %%
# Set the number of epochs for training
num_epochs = 100

# Set the batch size for training
batch_size = 32

# Fit the model
fit_history_3 = model_H2.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = num_epochs, batch_size = batch_size, verbose = 1)
# Out:
# Epoch 1/100
# 118/118 [==============================] - 1s 3ms/step - loss: 9.8143 - accuracy: 0.3285 - val_loss: 1.1465 - val_accuracy: 0.6440
# Epoch 2/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7269 - accuracy: 0.7544 - val_loss: 0.7333 - val_accuracy: 0.7736
# Epoch 3/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8485 - val_loss: 0.2976 - val_accuracy: 0.8912
# Epoch 4/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.9109 - val_loss: 0.3260 - val_accuracy: 0.8944
# Epoch 5/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1831 - accuracy: 0.9357 - val_loss: 0.2002 - val_accuracy: 0.9240
# Epoch 6/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1616 - accuracy: 0.9400 - val_loss: 0.1436 - val_accuracy: 0.9488
# Epoch 7/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9603 - val_loss: 0.2187 - val_accuracy: 0.9120
# Epoch 8/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9624 - val_loss: 0.1406 - val_accuracy: 0.9520
# Epoch 9/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9701 - val_loss: 0.2168 - val_accuracy: 0.9176
# Epoch 10/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9632 - val_loss: 0.0894 - val_accuracy: 0.9680
# Epoch 11/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9752 - val_loss: 0.1927 - val_accuracy: 0.9320
# Epoch 12/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0969 - accuracy: 0.9653 - val_loss: 0.2545 - val_accuracy: 0.9160
# Epoch 13/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0881 - accuracy: 0.9720 - val_loss: 0.1193 - val_accuracy: 0.9576
# Epoch 14/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9800 - val_loss: 0.1258 - val_accuracy: 0.9560
# Epoch 15/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0574 - accuracy: 0.9811 - val_loss: 0.0596 - val_accuracy: 0.9784
# Epoch 16/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 0.9805 - val_loss: 0.1650 - val_accuracy: 0.9456
# Epoch 17/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1068 - accuracy: 0.9624 - val_loss: 0.1111 - val_accuracy: 0.9672
# Epoch 18/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9755 - val_loss: 0.1306 - val_accuracy: 0.9544
# Epoch 19/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.9763 - val_loss: 0.1651 - val_accuracy: 0.9424
# Epoch 20/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9632 - val_loss: 0.4552 - val_accuracy: 0.8784
# Epoch 21/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9728 - val_loss: 0.1065 - val_accuracy: 0.9640
# Epoch 22/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9736 - val_loss: 0.1045 - val_accuracy: 0.9640
# Epoch 23/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9733 - val_loss: 0.2660 - val_accuracy: 0.9368
# Epoch 24/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9739 - val_loss: 0.0857 - val_accuracy: 0.9712
# Epoch 25/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0672 - accuracy: 0.9771 - val_loss: 0.1053 - val_accuracy: 0.9616
# Epoch 26/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1633 - accuracy: 0.9536 - val_loss: 0.1196 - val_accuracy: 0.9568
# Epoch 27/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9717 - val_loss: 0.1159 - val_accuracy: 0.9656
# Epoch 28/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9723 - val_loss: 0.1187 - val_accuracy: 0.9664
# Epoch 29/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9808 - val_loss: 0.0644 - val_accuracy: 0.9816
# Epoch 30/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0631 - accuracy: 0.9771 - val_loss: 0.0668 - val_accuracy: 0.9752
# Epoch 31/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 0.9843 - val_loss: 0.0711 - val_accuracy: 0.9768
# Epoch 32/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.9709 - val_loss: 0.1138 - val_accuracy: 0.9616
# Epoch 33/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9904 - val_loss: 0.1000 - val_accuracy: 0.9720
# Epoch 34/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 0.9715 - val_loss: 0.0570 - val_accuracy: 0.9784
# Epoch 35/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.9781 - val_loss: 0.1672 - val_accuracy: 0.9608
# Epoch 36/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9792 - val_loss: 0.0964 - val_accuracy: 0.9664
# Epoch 37/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9728 - val_loss: 0.1278 - val_accuracy: 0.9664
# Epoch 38/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9787 - val_loss: 0.0888 - val_accuracy: 0.9704
# Epoch 39/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0556 - accuracy: 0.9843 - val_loss: 0.1343 - val_accuracy: 0.9576
# Epoch 40/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1075 - accuracy: 0.9712 - val_loss: 0.0794 - val_accuracy: 0.9800
# Epoch 41/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9883 - val_loss: 0.1042 - val_accuracy: 0.9680
# Epoch 42/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9835 - val_loss: 0.0463 - val_accuracy: 0.9864
# Epoch 43/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9888 - val_loss: 0.0759 - val_accuracy: 0.9760
# Epoch 44/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9792 - val_loss: 0.0452 - val_accuracy: 0.9856
# Epoch 45/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 0.9808 - val_loss: 0.0928 - val_accuracy: 0.9752
# Epoch 46/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9925 - val_loss: 0.0912 - val_accuracy: 0.9728
# Epoch 47/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9824 - val_loss: 0.1321 - val_accuracy: 0.9576
# Epoch 48/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9888 - val_loss: 0.0536 - val_accuracy: 0.9832
# Epoch 49/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9856 - val_loss: 0.1041 - val_accuracy: 0.9680
# Epoch 50/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9883 - val_loss: 0.2170 - val_accuracy: 0.9480
# Epoch 51/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9869 - val_loss: 0.1367 - val_accuracy: 0.9608
# Epoch 52/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1434 - accuracy: 0.9611 - val_loss: 0.1144 - val_accuracy: 0.9680
# Epoch 53/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 0.9925 - val_loss: 0.0853 - val_accuracy: 0.9752
# Epoch 54/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 0.9856 - val_loss: 0.2063 - val_accuracy: 0.9560
# Epoch 55/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.9773 - val_loss: 0.0748 - val_accuracy: 0.9768
# Epoch 56/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9901 - val_loss: 0.0792 - val_accuracy: 0.9808
# Epoch 57/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9872 - val_loss: 0.0872 - val_accuracy: 0.9720
# Epoch 58/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9872 - val_loss: 0.0656 - val_accuracy: 0.9832
# Epoch 59/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 0.9925 - val_loss: 0.0938 - val_accuracy: 0.9728
# Epoch 60/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0655 - accuracy: 0.9803 - val_loss: 0.1002 - val_accuracy: 0.9744
# Epoch 61/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9851 - val_loss: 0.0635 - val_accuracy: 0.9800
# Epoch 62/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9904 - val_loss: 0.1414 - val_accuracy: 0.9688
# Epoch 63/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9755 - val_loss: 0.1792 - val_accuracy: 0.9488
# Epoch 64/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9893 - val_loss: 0.0880 - val_accuracy: 0.9824
# Epoch 65/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 0.0606 - val_accuracy: 0.9864
# Epoch 66/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9867 - val_loss: 0.0639 - val_accuracy: 0.9824
# Epoch 67/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9821 - val_loss: 0.1114 - val_accuracy: 0.9672
# Epoch 68/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9904 - val_loss: 0.0601 - val_accuracy: 0.9840
# Epoch 69/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.1343 - val_accuracy: 0.9760
# Epoch 70/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9925 - val_loss: 0.1100 - val_accuracy: 0.9752
# Epoch 71/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.1277 - val_accuracy: 0.9712
# Epoch 72/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9845 - val_loss: 0.1319 - val_accuracy: 0.9704
# Epoch 73/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9824 - val_loss: 0.1475 - val_accuracy: 0.9664
# Epoch 74/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9917 - val_loss: 0.1416 - val_accuracy: 0.9712
# Epoch 75/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9891 - val_loss: 0.1066 - val_accuracy: 0.9760
# Epoch 76/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1133 - accuracy: 0.9717 - val_loss: 0.2055 - val_accuracy: 0.9624
# Epoch 77/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9827 - val_loss: 0.0972 - val_accuracy: 0.9752
# Epoch 78/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9875 - val_loss: 0.0613 - val_accuracy: 0.9864
# Epoch 79/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1378 - accuracy: 0.9771 - val_loss: 0.0996 - val_accuracy: 0.9768
# Epoch 80/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9893 - val_loss: 0.0714 - val_accuracy: 0.9864
# Epoch 81/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9949 - val_loss: 0.0780 - val_accuracy: 0.9840
# Epoch 82/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0582 - val_accuracy: 0.9856
# Epoch 83/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0468 - val_accuracy: 0.9880
# Epoch 84/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0831 - val_accuracy: 0.9816
# Epoch 85/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9941 - val_loss: 0.0744 - val_accuracy: 0.9832
# Epoch 86/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.0798 - val_accuracy: 0.9784
# Epoch 87/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9949 - val_loss: 0.0729 - val_accuracy: 0.9848
# Epoch 88/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9925 - val_loss: 0.0474 - val_accuracy: 0.9872
# Epoch 89/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9880 - val_loss: 0.0768 - val_accuracy: 0.9832
# Epoch 90/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9912 - val_loss: 0.0540 - val_accuracy: 0.9856
# Epoch 91/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9957 - val_loss: 0.0884 - val_accuracy: 0.9784
# Epoch 92/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 0.9917 - val_loss: 0.1057 - val_accuracy: 0.9784
# Epoch 93/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9957 - val_loss: 0.0697 - val_accuracy: 0.9816
# Epoch 94/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0650 - val_accuracy: 0.9864
# Epoch 95/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0808 - val_accuracy: 0.9816
# Epoch 96/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9955 - val_loss: 0.0652 - val_accuracy: 0.9824
# Epoch 97/100
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0452 - val_accuracy: 0.9888
# Epoch 98/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.1036 - val_accuracy: 0.9792
# Epoch 99/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9917 - val_loss: 0.1035 - val_accuracy: 0.9808
# Epoch 100/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9928 - val_loss: 0.1294 - val_accuracy: 0.9712

# %%
# Set style as dark
sns.set_style("dark")

# Set figure size
plt.figure(figsize = (15, 8))

# Plot the title
plt.title("CONFUSION MATRIX FOR MNIST AUDIO PREDICTION WITH AN INPUT & AN OUTPUT LAYER")

# Confusion matrix
cm = confusion_matrix([int(x) for x in Y_test], Y_pred)

# Plot the confusion matrix as heatmap
sns.heatmap(cm, annot = True, cmap = "cool", fmt = 'g', cbar = False)

# Set X-label and Y-label
plt.xlabel("ACTUAL VALUES")
plt.ylabel("PREDICTED VALUES")

# Show the plot
plt.show()

# Print the metrics
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       119
#            1       1.00      0.98      0.99       133
#            2       0.98      0.99      0.98       128
#            3       0.96      0.96      0.96       112
#            4       1.00      1.00      1.00       136
#            5       1.00      1.00      1.00       127
#            6       1.00      1.00      1.00       133
#            7       1.00      0.99      1.00       116
#            8       1.00      0.98      0.99       125
#            9       0.98      1.00      0.99       121
#
#     accuracy                           0.99      1250
#    macro avg       0.99      0.99      0.99      1250
# weighted avg       0.99      0.99      0.99      1250

# %% [markdown]
# #### Observation:
# - Given a single input and output, the model still performs with an accuracy of 99% with only approximately 5,000 parameters.
# - This is a quarter of the original number of parameters while maintaining the same performance.
# - The accuracy of the first epoch was 0.3683 whereas the accuracy of the original model on the first epoch was higher: .4171.
# - The original model size was 164 kb in total with 25,000 parameters. With only 5000 parameters and 156 kb, the model is 4.0878% smaller on device.

# %% [markdown]
# #### Summary: The change in accuracy indicates that the model is a different architecture as the number of hidden layers is decreased even though the accuracy remains consistent at 99%.

# %%
dict_hist = fit_history.history

dict_hist_2 = fit_history_2.history

dict_hist_3 = fit_history_3.history

number_of_epochs = 35

list_ep = [i for i in range(1, number_of_epochs+1)]

list_ep30 = [i for i in range(1, number_of_epochs+1)]


plt.figure(figsize = (8, 8))

plt.plot(list_ep, dict_hist['accuracy'][:number_of_epochs], ls = '--', label = 'accuracy_1')

plt.plot(list_ep, dict_hist['val_accuracy'][:number_of_epochs], ls = '--', label = 'val_accuracy_1')

plt.plot(list_ep30, dict_hist_2['accuracy'][:number_of_epochs], label = 'accuracy_2')

plt.plot(list_ep30, dict_hist_2['val_accuracy'][:number_of_epochs], label = 'val_accuracy_2')

plt.plot(list_ep30, dict_hist_3['accuracy'][:number_of_epochs], label = 'accuracy_3')

plt.plot(list_ep30, dict_hist_3['val_accuracy'][:number_of_epochs], label = 'val_accuracy_3')

plt.ylabel('Accuracy')

plt.xlabel('Epochs')

plt.legend()

plt.show()

plt.figure(figsize = (8, 8))

plt.plot(list_ep, dict_hist['loss'][:number_of_epochs], ls = '-.', label = 'loss_1')

plt.plot(list_ep, dict_hist['val_loss'][:number_of_epochs], ls = '-.', label = 'val_loss_1')

plt.plot(list_ep30, dict_hist_2['loss'][:number_of_epochs], label = 'loss_2')

plt.plot(list_ep30, dict_hist_2['val_loss'][:number_of_epochs], label = 'val_loss_2')

plt.plot(list_ep30, dict_hist_3['loss'][:number_of_epochs], label = 'loss_3')

plt.plot(list_ep30, dict_hist_3['val_loss'][:number_of_epochs], label = 'val_loss_3')

plt.ylabel('Loss')

plt.xlabel('Epochs')

plt.legend()

plt.show()

# %% [markdown]
# ### Plot Summary
# From the plot above, it is apparent that the model loss stabilizes around 5 epochs, and the accuracy vs validation accuracy becomes stable at approximately 15 epochs. With the model being trained under 100 epochs, it is clear that less resources are required to accurately train this model.

# %% [markdown]
# ## **Conclusion**
#
# - **Digit Recognition, being an extremely small subset of the general category of Speech Recognition problems**, is simple enough that our Artificial Neural Network is able to achieve almost 100% accuracy.
# - Speech Recognition is a very active area of research, and **before the advent of Deep Learning, statistical machine learning methods did not do well** on the relatively straight forward problem statement of converting audio recordings of human speech into text.
# - In the industry, **Artificial Neural Networks being the simplest type of Deep Learning architecture find very limited use** and are mostly utilized only as a modular component of more advanced Deep Learning architectures.
# - However ANNs show their worth on tabular data sets which are highly numerical and high in volume - beyond a certain threshold in terms of number of instances, ANNs are able to learn fine patterns from the data in a way that Ensemble techniques or Support Vector Methods struggle to do so, and this is largely due to the hierarchical arrangement of the neurons in the Neural Network.
# - A digit speech recognition model such as the above may find use in certain applications for voice activated security applications with digit codes, automated telephone operators and the like. However, as always, business considerations such as compute efficiency and model robustness / security are required before such a model can be implemented in real-world settings.
